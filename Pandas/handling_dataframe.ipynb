# %%
import pandas as pd

# %%
import os
os.chdir('E:\\Data')

# %%
pd.read_csv('harsh.csv')
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
pf=pd.read_csv('E:\\MS Office\\harsh.csv')
pf
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date      Id
# 0  1      Dulce      Abril  Female  United States   32  15-10-2017  1562.0
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16-08-2016  1582.0
# 2  3     Philip       Gent    Male         France   36  21-05-2015  2587.0
# 3  4   Kathleen     Hanner  Female  United States   25  15-10-2017  3549.0
# 4  5    Nereida    Magwood     NaN  United States   58  16-08-2016  4523.0
# 5  6     Gaston      Brumm    Male  United States   24  21-05-2015     NaN
# 6  7       Etta       Hurn  Female  Great Britain   56  15-10-2017  3598.0
# 7  8    Earlean     Melgar  Female  United States   27  16-08-2016  2456.0
# 8  9   Vincenza    Weiland     NaN  United States   40  21-05-2015     NaN

# %%
pd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ae60287777ef> in <module>
# ----> 1 pd.head()
#
# c:\python 3.7\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'head'

# %%
pf.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
pf.tail()
# Out:
#    0 First Name Last Name  Gender        Country  Age        Date    Id
# 4  5    Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston     Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta      Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean    Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza   Weiland  Female  United States   40  21/05/2015  6548

# %%
dtype(pf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-132f3e9a4319> in <module>
# ----> 1 dtype(pf)
#
# NameError: name 'dtype' is not defined

# %%
pf=pd.read_csv('E:\\harsh.csv',nrows=1)
pf
# Out:
#    0 First Name Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce     Abril  Female  United States   32  15/10/2017  1562

# %%
pf=pd.read_csv('E:\\harsh.csv',nrows=5)
pf
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
pf=pd.read_csv('E:\\MS Office\\harsh.csv',skiprows=5)
pf
# Out:
#    5   Nereida  Magwood Unnamed: 3  United States  58  16-08-2016    4523
# 0  6    Gaston    Brumm       Male  United States  24  21-05-2015     NaN
# 1  7      Etta     Hurn     Female  Great Britain  56  15-10-2017  3598.0
# 2  8   Earlean   Melgar     Female  United States  27  16-08-2016  2456.0
# 3  9  Vincenza  Weiland        NaN  United States  40  21-05-2015     NaN

# %%
pf=pd.read_csv('E:\\MS Office\\harsh.csv',skiprows=[5])
pf
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date      Id
# 0  1      Dulce      Abril  Female  United States   32  15-10-2017  1562.0
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16-08-2016  1582.0
# 2  3     Philip       Gent    Male         France   36  21-05-2015  2587.0
# 3  4   Kathleen     Hanner  Female  United States   25  15-10-2017  3549.0
# 4  6     Gaston      Brumm    Male  United States   24  21-05-2015     NaN
# 5  7       Etta       Hurn  Female  Great Britain   56  15-10-2017  3598.0
# 6  8    Earlean     Melgar  Female  United States   27  16-08-2016  2456.0
# 7  9   Vincenza    Weiland     NaN  United States   40  21-05-2015     NaN

# %%
pf=pd.read_csv('E:\\MS Office\\harsh.csv')
pf
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date      Id
# 0  1      Dulce      Abril  Female  United States   32  15-10-2017  1562.0
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16-08-2016  1582.0
# 2  3     Philip       Gent    Male         France   36  21-05-2015  2587.0
# 3  4   Kathleen     Hanner  Female  United States   25  15-10-2017  3549.0
# 4  5    Nereida    Magwood     NaN  United States   58  16-08-2016  4523.0
# 5  6     Gaston      Brumm    Male  United States   24  21-05-2015     NaN
# 6  7       Etta       Hurn  Female  Great Britain   56  15-10-2017  3598.0
# 7  8    Earlean     Melgar  Female  United States   27  16-08-2016  2456.0
# 8  9   Vincenza    Weiland     NaN  United States   40  21-05-2015     NaN

# %%
pf=pd.read_csv('E:\\MS Office\\harsh.csv',index_col=2)
pf
# Out:
#            0 First Name  Gender        Country  Age        Date      Id
# Last Name
# Abril      1      Dulce  Female  United States   32  15-10-2017  1562.0
# Hashimoto  2       Mara  Female  Great Britain   25  16-08-2016  1582.0
# Gent       3     Philip    Male         France   36  21-05-2015  2587.0
# Hanner     4   Kathleen  Female  United States   25  15-10-2017  3549.0
# Magwood    5    Nereida     NaN  United States   58  16-08-2016  4523.0
# Brumm      6     Gaston    Male  United States   24  21-05-2015     NaN
# Hurn       7       Etta  Female  Great Britain   56  15-10-2017  3598.0
# Melgar     8    Earlean  Female  United States   27  16-08-2016  2456.0
# Weiland    9   Vincenza     NaN  United States   40  21-05-2015     NaN

# %%
pf=pd.read_csv('E:\\MS Office\\harsh.csv',usecols=['Id'])
pf
# Out:
#        Id
# 0  1562.0
# 1  1582.0
# 2  2587.0
# 3  3549.0
# 4  4523.0
# 5     NaN
# 6  3598.0
# 7  2456.0
# 8     NaN

# %%
pf=pd.read_csv('E:\\harsh.csv',index_col=1)
pf
# Out:
#             0  Last Name  Gender        Country  Age        Date    Id
# First Name
# Dulce       1      Abril  Female  United States   32  15/10/2017  1562
# Mara        2  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# Philip      3       Gent    Male         France   36  21/05/2015  2587
# Kathleen    4     Hanner  Female  United States   25  15/10/2017  3549
# Nereida     5    Magwood  Female  United States   58  16/08/2016  2468
# Gaston      6      Brumm    Male  United States   24  21/05/2015  2554
# Etta        7       Hurn  Female  Great Britain   56  15/10/2017  3598
# Earlean     8     Melgar  Female  United States   27  16/08/2016  2456
# Vincenza    9    Weiland  Female  United States   40  21/05/2015  6548

# %%
pf=pd.read_csv('E:\\harsh.csv',usecols=[2])
pf
# Out:
#    Last Name
# 0      Abril
# 1  Hashimoto
# 2       Gent
# 3     Hanner
# 4    Magwood
# 5      Brumm
# 6       Hurn
# 7     Melgar
# 8    Weiland

# %%
pf=pd.read_csv('E:\\MS Office\\harsh.csv')
pf
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date      Id
# 0  1      Dulce      Abril  Female  United States   32  15-10-2017  1562.0
# 1  2       Mara  Hashimoto  Female  Great Britain   25  
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-880f7da5b0ef> in <module>
# ----> 1 pf=pd.read_csv('E:\\harsh.csv',header=None, names=['a','b','c','d','e','f','g','h'])
#       2 pf
#
# c:\python 3.7\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
pf=pd.read_csv('E:\\harsh.csv',names=['a','b','c','d','e','f','g','h'])
pf
# Out:
#    a           b          c       d              e    f           g     h
# 0  0  First Name  Last Name  Gender        Country  Age        Date    Id
# 1  1       Dulce      Abril  Female  United States   32  15/10/2017  1562
# 2  2        Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3  3      Philip       Gent    Male         France   36  21/05/2015  2587
# 4  4    Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 5  5     Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 6  6      Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 7  7        Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 8  8     Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 9  9    Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
pf.tail()
# Out:
#    a         b        c       d              e   f           g     h
# 5  5   Nereida  Magwood  Female  United States  58  16/08/2016  2468
# 6  6    Gaston    Brumm    Male  United States  24  21/05/2015  2554
# 7  7      Etta     Hurn  Female  Great Britain  56  15/10/2017  3598
# 8  8   Earlean   Melgar  Female  United States  27  16/08/2016  2456
# 9  9  Vincenza  Weiland  Female  United States  40  21/05/2015  6548

# %%
pf.tail(3)
# Out:
#    a         b        c       d              e   f           g     h
# 7  7      Etta     Hurn  Female  Great Britain  56  15/10/2017  3598
# 8  8   Earlean   Melgar  Female  United States  27  16/08/2016  2456
# 9  9  Vincenza  Weiland  Female  United States  40  21/05/2015  6548

# %%
pf
# Out:
#    a           b          c       d              e    f           g     h
# 0  0  First Name  Last Name  Gender        Country  Age        Date    Id
# 1  1       Dulce      Abril  Female  United States   32  15/10/2017  1562
# 2  2        Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3  3      Philip       Gent    Male         France   36  21/05/2015  2587
# 4  4    Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 5  5     Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 6  6      Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 7  7        Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 8  8     Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 9  9    Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
pf=pd.read_csv('E:\\harsh.csv',header=1)
pf
# Out:
#    1     Dulce      Abril  Female  United States  32  15/10/2017  1562
# 0  2      Mara  Hashimoto  Female  Great Britain  25  16/08/2016  1582
# 1  3    Philip       Gent    Male         France  36  21/05/2015  2587
# 2  4  Kathleen     Hanner  Female  United States  25  15/10/2017  3549
# 3  5   Nereida    Magwood  Female  United States  58  16/08/2016  2468
# 4  6    Gaston      Brumm    Male  United States  24  21/05/2015  2554
# 5  7      Etta       Hurn  Female  Great Britain  56  15/10/2017  3598
# 6  8   Earlean     Melgar  Female  United States  27  16/08/2016  2456
# 7  9  Vincenza    Weiland  Female  United States  40  21/05/2015  6548

# %%
pf=pd.read_csv('E:\\harsh.csv',header=0)
pf
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
pf=pd.read_csv('E:\\harsh.csv',dtype={'Id':'float'})
pf
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date      Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562.0
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582.0
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587.0
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549.0
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468.0
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554.0
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598.0
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456.0
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548.0
